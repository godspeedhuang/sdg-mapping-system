# %%
import pandas as pd
df = pd.read_csv('test3.csv')
df.sort_values(by=['0'], ascending=False)
# Out:
#      Unnamed: 0               id  goal  \
# 126         126  Indicator10-1-1    10
# 1             1   Indicator1-2-1     1
# 2             2   Indicator1-2-2     1
# 0             0   Indicator1-1-1     1
# 127         127  Indicator10-2-1    10
# ..          ...              ...   ...
# 89           89   Indicator6-6-1     6
# 88           88   Indicator6-5-2     6
# 68           68   Indicator5-2-1     5
# 49           49   Indicator3-b-1     3
# 211         211  Indicator16-4-2    16
#
#                                              indicator  \
# 126  Growth rates of household expenditure or incom...
# 1    Proportion of population living below the nati...
# 2    Proportion of men, women and children of all a...
# 0    Proportion of the population living below the ...
# 127  Proportion of people living below 50 per cent ...
# ..                                                 ...
# 89   Change in the extent of water-related ecosyste...
# ...
